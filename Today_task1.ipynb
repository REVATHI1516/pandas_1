# %%
#beer text

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd

# %%
chipotle_url = "https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv"

# %%
df=pd.read_csv(chipotle_url,sep='\t')

# %%
df.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
df.tail(10)
# Out:
#       order_id  quantity            item_name  \
# 4612      1831         1        Carnitas Bowl
# 4613      1831         1                Chips
# 4614      1831         1        Bottled Water
# 4615      1832         1   Chicken Soft Tacos
# 4616      1832         1  Chips and Guacamole
# 4617      1833         1        Steak Burrito
# 4618      1833         1        Steak Burrito
# 4619      1834         1   Chicken Salad Bowl
# 4620      1834         1   Chicken Salad Bowl
# 4621      1834         1   Chicken Salad Bowl
#
#                                      choice_description item_price
# 4612  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...     $9.25
# 4613                                                NaN     $2.15
# 4614                                                NaN     $1.50
# 4615   [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]     $8.75
# 4616                                                NaN     $4.45
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
df.shape[1]
# Out:
# 5

# %%
df.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
a= df.groupby('choice_description')
a = a.sum()
a = a.sort_values(['quantity'], ascending=False)
a.head()
# Out:
#                                                     order_id  quantity
# choice_description
# [Diet Coke]                                           123455       159
# [Coke]                                                122752       143
# [Sprite]                                               80426        89
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese...     43088        49
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese...     36041        42

# %%
a.head(2)
# Out:
#                     order_id  quantity
# choice_description
# [Diet Coke]           123455       159
# [Coke]                122752       143

# %%
b = df.groupby('item_name').sum()
b = b.sort_values(['quantity'], ascending=True)
b.head()
# Out:
#                                    order_id  quantity
# item_name
# Carnitas Salad                         1500         1
# Veggie Crispy Tacos                     668         1
# Chips and Mild Fresh Tomato Salsa       279         1
# Crispy Tacos                            434         2
# Salad                                  1150         2

# %%
b.head(3)
# Out:
#                                    order_id  quantity
# item_name
# Carnitas Salad                         1500         1
# Veggie Crispy Tacos                     668         1
# Chips and Mild Fresh Tomato Salsa       279         1

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
a=lambda x: float(x[1:-1])

# %%
df.item_price = df.item_price.apply(a)

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
filtered = df.drop_duplicates(['item_name','quantity'])
prod_one = filtered[filtered.quantity == 1]
price_per_item = prod_one[['item_name', 'item_price']]
price_per_item.sort_values(by = "item_price", ascending = False)
# Out:
#                                   item_name  item_price
# 606                        Steak Salad Bowl       11.89
# 1229                    Barbacoa Salad Bowl       11.89
# 1132                    Carnitas Salad Bowl       11.89
# 7                             Steak Burrito       11.75
# 168                   Barbacoa Crispy Tacos       11.75
# 39                            Barbacoa Bowl       11.75
# 738                       Veggie Soft Tacos       11.25
# 186                       Veggie Salad Bowl       11.25
# 62                              Veggie Bowl       11.25
# 57                           Veggie Burrito       11.25
# 250                           Chicken Salad       10.98
# 5                              Chicken Bowl       10.98
# 8                          Steak Soft Tacos        9.25
# 554                   Carnitas Crispy Tacos        9.25
# 237                     Carnitas Soft Tacos        9.25
# 56                      Barbacoa Soft Tacos        9.25
# ...

# %%
df.sort_values(by = "item_price", ascending = False).head()
# Out:
#       order_id  quantity                     item_name  \
# 3598      1443        15  Chips and Fresh Tomato Salsa
# 3480      1398         3                 Carnitas Bowl
# 1254       511         4               Chicken Burrito
# 3602      1443         4               Chicken Burrito
# 3601      1443         3                Veggie Burrito
#
#                                      choice_description  item_price
# 3598                                                NaN       44.25
# 3480  [Roasted Chili Corn Salsa, [Fajita Vegetables,...       35.25
# 1254  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       35.00
# 3602  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...       35.00
# 3601  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       33.75

# %%
df[df.item_name == "Chicken Salad Bowl"]
# Out:
#       order_id  quantity           item_name  \
# 44          20         1  Chicken Salad Bowl
# 135         60         2  Chicken Salad Bowl
# 213         94         2  Chicken Salad Bowl
# 256        111         1  Chicken Salad Bowl
# 315        137         2  Chicken Salad Bowl
# ...        ...       ...                 ...
# 4561      1813         2  Chicken Salad Bowl
# 4580      1822         1  Chicken Salad Bowl
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description  item_price
# 44    [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...        8.75
# 135   [Tomatillo Green Chili Salsa, [Sour Cream, Che...       22.50
# 213   [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...       22.50
# 256   [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...        8.75
# 315             [Fresh Tomato Salsa, Fajita Vegetables]       17.50
# ...

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as p

# %%
url = "https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv"
crime = pd.read_csv(url)
crime.head()
# Out:
#    Year  Population    Total  Violent  Property  Murder  Forcible_Rape  \
# 0  1960   179323175  3384200   288460   3095700    9110          17190
# 1  1961   182992000  3488000   289390   3198600    8740          17220
# 2  1962   185771000  3752200   301510   3450700    8530          17550
# 3  1963   188483000  4109500   316970   3792500    8640          17650
# 4  1964   191141000  4564600   364220   4200400    9360          21420
#
#    Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0   107840              154320    912100        1855400         328200
# 1   106670              156760    949600        1913000         336000
# 2   110860              164570    994300        2089600         366800
# 3   116470              174210   1086400        2297800         408300
# 4   130390              203050   1213200        2514400         472800

# %%
crime.Year = pd.to_datetime(crime.Year, format='%Y')
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                55 non-null     datetime64[ns]
#  1   Population          55 non-null     int64
#  2   Total               55 non-null     int64
#  3   Violent             55 non-null     int64
#  4   Property            55 non-null     int64
#  5   Murder              55 non-null     int64
#  6   Forcible_Rape       55 non-null     int64
#  7   Robbery             55 non-null     int64
#  8   Aggravated_assault  55 non-null     int64
#  9   Burglary            55 non-null     int64
#  10  Larceny_Theft       55 non-null     int64
#  11  Vehicle_Theft       55 non-null     int64
# dtypes: datetime64[ns](1), int64(11)
# memory usage: 5.3 KB

# %%
crime
# Out:
#             Population     Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01   179323175   3384200   288460   3095700    9110          17190
# 1961-01-01   182992000   3488000   289390   3198600    8740          17220
# 1962-01-01   185771000   3752200   301510   3450700    8530          17550
# 1963-01-01   188483000   4109500   316970   3792500    8640          17650
# 1964-01-01   191141000   4564600   364220   4200400    9360          21420
# 1965-01-01   193526000   4739400   387390   4352000    9960          23410
# 1966-01-01   195576000   5223500   430180   4793300   11040          25820
# 1967-01-01   197457000   5903400   499930   5403500   12240          27620
# 1968-01-01   199399000   6720200   595010   6125200   13800          31670
# 1969-01-01   201385000   7410900   661870   6749000   14760          37170
# 1970-01-01   203235298   8098000   738820   7359200   16000          37990
# ...

# %%
df=crime

# %%
df.iloc[2:5]
# Out:
#             Population    Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1962-01-01   185771000  3752200   301510   3450700    8530          17550
# 1963-01-01   188483000  4109500   316970   3792500    8640          17650
# 1964-01-01   191141000  4564600   364220   4200400    9360          21420
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1962-01-01   110860              164570    994300        2089600
# 1963-01-01   116470              174210   1086400        2297800
# 1964-01-01   130390              203050   1213200        2514400
#
#             Vehicle_Theft
# Year
# 1962-01-01         366800
# 1963-01-01         408300
# 1964-01-01         472800

# %%
df.loc[:, ['Murder', 'Robbery']].head()
# Out:
#             Murder  Robbery
# Year
# 1960-01-01    9110   107840
# 1961-01-01    8740   106670
# 1962-01-01    8530   110860
# 1963-01-01    8640   116470
# 1964-01-01    9360   130390

# %%
df[['Murder', 'Robbery']].head()
# Out:
#             Murder  Robbery
# Year
# 1960-01-01    9110   107840
# 1961-01-01    8740   106670
# 1962-01-01    8530   110860
# 1963-01-01    8640   116470
# 1964-01-01    9360   130390

# %%
df.loc[df.index[[6,7,8]], ['Murder', 'Robbery']]
# Out:
#             Murder  Robbery
# Year
# 1966-01-01   11040   157990
# 1967-01-01   12240   202910
# 1968-01-01   13800   262840

# %%
df
# Out:
#             Population     Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01   179323175   3384200   288460   3095700    9110          17190
# 1961-01-01   182992000   3488000   289390   3198600    8740          17220
# 1962-01-01   185771000   3752200   301510   3450700    8530          17550
# 1963-01-01   188483000   4109500   316970   3792500    8640          17650
# 1964-01-01   191141000   4564600   364220   4200400    9360          21420
# 1965-01-01   193526000   4739400   387390   4352000    9960          23410
# 1966-01-01   195576000   5223500   430180   4793300   11040          25820
# 1967-01-01   197457000   5903400   499930   5403500   12240          27620
# 1968-01-01   199399000   6720200   595010   6125200   13800          31670
# 1969-01-01   201385000   7410900   661870   6749000   14760          37170
# 1970-01-01   203235298   8098000   738820   7359200   16000          37990
# ...

# %%
#Select only the rows where the number of murder is greater than 24,000
df[df['Vehicle_Theft'] > 50000].head(10)
# Out:
#             Population    Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01   179323175  3384200   288460   3095700    9110          17190
# 1961-01-01   182992000  3488000   289390   3198600    8740          17220
# 1962-01-01   185771000  3752200   301510   3450700    8530          17550
# 1963-01-01   188483000  4109500   316970   3792500    8640          17650
# 1964-01-01   191141000  4564600   364220   4200400    9360          21420
# 1965-01-01   193526000  4739400   387390   4352000    9960          23410
# 1966-01-01   195576000  5223500   430180   4793300   11040          25820
# 1967-01-01   197457000  5903400   499930   5403500   12240          27620
# 1968-01-01   199399000  6720200   595010   6125200   13800          31670
# 1969-01-01   201385000  7410900   661870   6749000   14760          37170
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1960-01-01   107840              154320    912100        1855400
# ...

# %%
df.groupby('Year')['Vehicle_Theft'].mean()
# Out:
# Year
# 1960-01-01     328200
# 1961-01-01     336000
# 1962-01-01     366800
# 1963-01-01     408300
# 1964-01-01     472800
# 1965-01-01     496900
# 1966-01-01     561200
# 1967-01-01     659800
# 1968-01-01     783600
# 1969-01-01     878500
# 1970-01-01     928400
# 1971-01-01     948200
# 1972-01-01     887200
# 1973-01-01     928800
# 1974-01-01     977100
# 1975-01-01    1009600
# 1976-01-01     966000
# 1977-01-01     977700
# 1978-01-01    1004100
# 1979-01-01    1112800
# 1980-01-01    1131700
# 1981-01-01    1087800
# 1982-01-01    1062400
# 1983-01-01    1007900
# 1984-01-01    1032200
# 1985-01-01    1102900
# 1986-01-01    1224137
# 1987-01-01    1288674
# 1988-01-01    1432900
# 1989-01-01    1564800
# 1990-01-01    1635900
# 1991-01-01    1661700
# 1992-01-01    1610800
# 1993-01-01    1563100
# 1994-01-01    1539300
# 1995-01-01    1472400
# 1996-01-01    1394200
# 1997-01-01    1354189
# 1998-01-01    1240754
# 1999-01-01    1152075
# 2000-01-01    1160002
# ...

# %%
df.sort_values(by=['Murder', 'Violent'], ascending=[True,True])
# Out:
#             Population     Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1962-01-01   185771000   3752200   301510   3450700    8530          17550
# 1963-01-01   188483000   4109500   316970   3792500    8640          17650
# 1961-01-01   182992000   3488000   289390   3198600    8740          17220
# 1960-01-01   179323175   3384200   288460   3095700    9110          17190
# 1964-01-01   191141000   4564600   364220   4200400    9360          21420
# 1965-01-01   193526000   4739400   387390   4352000    9960          23410
# 1966-01-01   195576000   5223500   430180   4793300   11040          25820
# 1967-01-01   197457000   5903400   499930   5403500   12240          27620
# 1968-01-01   199399000   6720200   595010   6125200   13800          31670
# 2014-01-01   318857056   9475816  1197987   8277829   14249          84041
# 2013-01-01   316497531   9850445  1199684   8650761   14319          82109
# ...

# %%
df = pd.read_csv('https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/datasets.csv')

# %%
df
# Out:
#      Package           Item  \
# 0        AER        Affairs
# 1        AER   ArgentinaCPI
# 2        AER      BankWages
# 3        AER  BenderlyZwick
# 4        AER      BondYield
# ...      ...            ...
# 1709     vcd       UKSoccer
# 1710     vcd   VisualAcuity
# 1711     vcd        VonBort
# 1712     vcd     WeldonDice
# 1713     vcd     WomenQueue
#
#                                                   Title  Rows  Cols  n_binary  \
# 0                      Fair's Extramarital Affairs Data   601     9         2
# 1                     Consumer Price Index in Argentina    80     2         0
# 2                                            Bank Wages   474     4         2
# 3     Benderly and Zwick Data: Inflation, Growth and...    31     5         0
# 4                                       Bond Yield Data    60     2         0
# ...                                                 ...   ...   ...       ...
# ...

# %%
df.head()
# Out:
#   Package           Item                                              Title  \
# 0     AER        Affairs                   Fair's Extramarital Affairs Data
# 1     AER   ArgentinaCPI                  Consumer Price Index in Argentina
# 2     AER      BankWages                                         Bank Wages
# 3     AER  BenderlyZwick  Benderly and Zwick Data: Inflation, Growth and...
# 4     AER      BondYield                                    Bond Yield Data
#
#    Rows  Cols  n_binary  n_character  n_factor  n_logical  n_numeric  \
# 0   601     9         2            0         2          0          7
# 1    80     2         0            0         0          0          2
# 2   474     4         2            0         3          0          1
# 3    31     5         0            0         0          0          5
# 4    60     2         0            0         0          0          2
#
#                                                  CSV  \
# ...

# %%
df['CSV'][df['Package']=='AER']
# Out:
# 0      https://vincentarelbundock.github.io/Rdatasets...
# 1      https://vincentarelbundock.github.io/Rdatasets...
# 2      https://vincentarelbundock.github.io/Rdatasets...
# 3      https://vincentarelbundock.github.io/Rdatasets...
# 4      https://vincentarelbundock.github.io/Rdatasets...
#                              ...
# 102    https://vincentarelbundock.github.io/Rdatasets...
# 103    https://vincentarelbundock.github.io/Rdatasets...
# 104    https://vincentarelbundock.github.io/Rdatasets...
# 105    https://vincentarelbundock.github.io/Rdatasets...
# 106    https://vincentarelbundock.github.io/Rdatasets...
# Name: CSV, Length: 107, dtype: object

# %%
df['CSV'][df['Package']=='AER'].head(5)
# Out:
# 0    https://vincentarelbundock.github.io/Rdatasets...
# 1    https://vincentarelbundock.github.io/Rdatasets...
# 2    https://vincentarelbundock.github.io/Rdatasets...
# 3    https://vincentarelbundock.github.io/Rdatasets...
# 4    https://vincentarelbundock.github.io/Rdatasets...
# Name: CSV, dtype: object

# %%
df.tail()
# Out:
#      Package          Item                                 Title  Rows  Cols  \
# 1709     vcd      UKSoccer                      UK Soccer Scores    25     3
# 1710     vcd  VisualAcuity  Visual Acuity in Left and Right Eyes    32     4
# 1711     vcd       VonBort      Von Bortkiewicz Horse Kicks Data   280     4
# 1712     vcd    WeldonDice                    Weldon's Dice Data    11     2
# 1713     vcd    WomenQueue                       Women in Queues    11     2
#
#       n_binary  n_character  n_factor  n_logical  n_numeric  \
# 1709         0            0         2          0          1
# 1710         1            0         3          0          1
# 1711         1            0         2          0          2
# 1712         0            0         1          0          1
# 1713         0            0         1          0          1
#
#                                                     CSV  \
# 1709  https://vincentarelbundock.github.io/Rdatasets...
# ...

# %%
df.sort_values(by=['Cols'], ascending=[True]).head(10)
# Out:
#          Package                   Item  \
# 57           AER        MSCISwitzerland
# 129         boot                 darwin
# 1011  mosaicData                  Cards
# 128         boot                   coal
# 232   causaldata  gov_transfers_density
# 1148   openintro           male_heights
# 1149   openintro      male_heights_fcid
# 1058   openintro           ball_bearing
# 1140   openintro               leg_mari
# 153         boot                   tuna
#
#                                                   Title   Rows  Cols  \
# 57                               MSCI Switzerland Index   4697     1
# 129                   Darwin's Plant Height Differences     15     1
# 1011                             Standard Deck of Cards     52     1
# 128                      Dates of Coal Mining Disasters    191     1
# 232   Data from "Government Transfers and Political ...  52549     1
# 1148                         Sample of 100 male heights    100     1
# ...

# %%
df.sort_values(by=['Rows','Cols'], ascending=[True,True]).head(10)
# Out:
#         Package               Item  \
# 1395  Stat2Data           ChemoTHC
# 1491  Stat2Data          Migraines
# 1556  Stat2Data                TMS
# 1307   reshape2             smiths
# 1671      tidyr             smiths
# 723         gap           jma.cojo
# 1106  openintro        fish_oil_18
# 487       dplyr   band_instruments
# 488       dplyr  band_instruments2
# 489       dplyr       band_members
#
#                                                   Title  Rows  Cols  n_binary  \
# 1395       THC for Antinausea Treatment in Chemotherapy     2     4         4
# 1491                                  Migraines and TMS     2     4         3
# 1556                                  Migraines and TMS     2     4         3
# 1307                   Demo data describing the Smiths.     2     5         2
# 1671                   Some data about the Smith family     2     5         2
# 723                          Internal functions for gap     2    16        13
# ...

# %%
df.head()
# Out:
#   Package           Item                                              Title  \
# 0     AER        Affairs                   Fair's Extramarital Affairs Data
# 1     AER   ArgentinaCPI                  Consumer Price Index in Argentina
# 2     AER      BankWages                                         Bank Wages
# 3     AER  BenderlyZwick  Benderly and Zwick Data: Inflation, Growth and...
# 4     AER      BondYield                                    Bond Yield Data
#
#    Rows  Cols  n_binary  n_character  n_factor  n_logical  n_numeric  \
# 0   601     9         2            0         2          0          7
# 1    80     2         0            0         0          0          2
# 2   474     4         2            0         3          0          1
# 3    31     5         0            0         0          0          5
# 4    60     2         0            0         0          0          2
#
#                                                  CSV  \
# ...

# %%
df.groupby('Package')['Rows'].mean()
# Out:
# Package
# AER                5182.205607
# COUNT              3304.142857
# DAAG                841.975207
# Ecdat              2102.365672
# HLMdiag            2063.750000
# HSAUR               119.829268
# HistData            260.434783
# ISLR               1898.923077
# KMsurv              309.703704
# MASS                231.264368
# Stat2Data          1476.573460
# boot                299.979592
# carData            2424.507937
# causaldata        13647.333333
# cluster             379.666667
# datasets            296.023810
# dplyr              2021.200000
# dragracer           734.666667
# drc                  72.657143
# evir               4292.571429
# forecast           1182.200000
# fpp2               1438.105263
# gap                 435.000000
# geepack            2237.555556
# ggplot2            6744.363636
# ggplot2movies     58788.000000
# gt                13253.666667
# hwde                 22.500000
# lattice             147.285714
# lme4               7527.545455
# ...

# %%
df.head()
# Out:
#   Package           Item                                              Title  \
# 0     AER        Affairs                   Fair's Extramarital Affairs Data
# 1     AER   ArgentinaCPI                  Consumer Price Index in Argentina
# 2     AER      BankWages                                         Bank Wages
# 3     AER  BenderlyZwick  Benderly and Zwick Data: Inflation, Growth and...
# 4     AER      BondYield                                    Bond Yield Data
#
#    Rows  Cols  n_binary  n_character  n_factor  n_logical  n_numeric  \
# 0   601     9         2            0         2          0          7
# 1    80     2         0            0         0          0          2
# 2   474     4         2            0         3          0          1
# 3    31     5         0            0         0          0          5
# 4    60     2         0            0         0          0          2
#
#                                                  CSV  \
# ...

# %%
df[df['Rows'] > 500].head(5)
# Out:
#    Package             Item                                  Title   Rows  \
# 0      AER          Affairs       Fair's Extramarital Affairs Data    601
# 10     AER  CollegeDistance                  College Distance Data   4739
# 12     AER          CPS1985  Determinants of Wages Data (CPS 1985)    534
# 13     AER          CPS1988  Determinants of Wages Data (CPS 1988)  28155
# 14     AER          CPSSW04         Stock and Watson CPS Data Sets   7986
#
#     Cols  n_binary  n_character  n_factor  n_logical  n_numeric  \
# 0      9         2            0         2          0          7
# 10    14         7            0         8          0          6
# 12    11         4            0         7          0          4
# 13     7         3            0         4          0          3
# 14     4         2            0         2          0          2
#
#                                                   CSV  \
# 0   https://vincentarelbundock.github.io/Rdatasets...
# ...

# %%
df.head()
# Out:
#   Package           Item                                              Title  \
# 0     AER        Affairs                   Fair's Extramarital Affairs Data
# 1     AER   ArgentinaCPI                  Consumer Price Index in Argentina
# 2     AER      BankWages                                         Bank Wages
# 3     AER  BenderlyZwick  Benderly and Zwick Data: Inflation, Growth and...
# 4     AER      BondYield                                    Bond Yield Data
#
#    Rows  Cols  n_binary  n_character  n_factor  n_logical  n_numeric  \
# 0   601     9         2            0         2          0          7
# 1    80     2         0            0         0          0          2
# 2   474     4         2            0         3          0          1
# 3    31     5         0            0         0          0          5
# 4    60     2         0            0         0          0          2
#
#                                                  CSV  \
# ...

# %%
df.loc[df.index[[5,9,10]], ['Item', 'CSV']]
# Out:
#                Item                                                CSV
# 5   CartelStability  https://vincentarelbundock.github.io/Rdatasets...
# 9      CigarettesSW  https://vincentarelbundock.github.io/Rdatasets...
# 10  CollegeDistance  https://vincentarelbundock.github.io/Rdatasets...
